# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report
import os

# %%
class EmotionCauseDataset(Dataset):
    def __init__(self, csv_file, feature_dir):
        """
        Args:
            csv_file: Path to the CSV file with dialogue data
            feature_dir: Directory containing feature files
        """
        self.df = pd.read_csv(csv_file)
        self.feature_dir = feature_dir
        
        # Process the dataframe to group by dialogue_id
        self.dialogues = self.process_dialogues()
        
        # Determine feature dimensions
        self.feature_dims = self.get_feature_dimensions()
        print(f"Feature dimensions: {self.feature_dims}")
        
    def get_feature_dimensions(self):
        """Determine the feature dimensions by examining the first available file for each modality"""
        dims = {}
        
        # Get a dialogue ID and utterance ID from the data
        dialogue_id = self.dialogues[0]['dialogue_id']
        
        # Check text feature dimension
        text_path = os.path.join(self.feature_dir, 'text', f'text_feature_{dialogue_id}_0.npy')
        if os.path.exists(text_path):
            text_feat = np.load(text_path)
            dims['text'] = text_feat.shape[0]
        else:
            dims['text'] = 768  # Default
            
        # Check audio feature dimension
        audio_path = os.path.join(self.feature_dir, 'audio', f'audio_feature_{dialogue_id}_0.npy')
        if os.path.exists(audio_path):
            audio_feat = np.load(audio_path)
            dims['audio'] = audio_feat.shape[0]
        else:
            dims['audio'] = 1024  # Default, updated based on error
            
        # Check video feature dimension
        video_path = os.path.join(self.feature_dir, 'video', f'video_feature_{dialogue_id}_0.npy')
        if os.path.exists(video_path):
            video_feat = np.load(video_path)
            dims['video'] = video_feat.shape[0]
        else:
            dims['video'] = 2048  # Default
            
        return dims
        
    def process_dialogues(self):
        """Process the dataframe to group utterances by dialogue_id with unified label encoding"""
        dialogues = []
        
        # Group by Dialogue_ID
        for dialogue_id, group in self.df.groupby('Dialogue_ID'):
            utterances = []
            unified_target = []
            
            # Sort by Utterance_ID to ensure correct sequence
            group = group.sort_values('Utterance_ID')
            
            for _, row in group.iterrows():
                utterances.append(row['Utterance'])
                
                # Unified label encoding: 0=neutral, 1=anger, 2=cause
                if row['Label'] == 'cause':
                    unified_target.append(2)  # cause
                elif row['Label'] != 'neutral' and row['Emotion'] != 'neutral':
                    unified_target.append(1)  # anger
                else:
                    unified_target.append(0)  # neutral
            
            dialogues.append({
                'dialogue_id': int(dialogue_id),
                'utterances': utterances,
                'unified_target': unified_target,
                'num_utterances': len(utterances)
            })
        
        return dialogues
    
    def __len__(self):
        return len(self.dialogues)

    def __getitem__(self, idx):
        dialogue = self.dialogues[idx]
        dialogue_id = dialogue['dialogue_id']
        num_utterances = dialogue['num_utterances']
        
        # Load features for each utterance
        text_features = []
        audio_features = []
        video_features = []
        
        for utt_id in range(num_utterances):
            # Load text features
            text_path = os.path.join(self.feature_dir, 'text', f'text_feature_{dialogue_id}_{utt_id}.npy')
            if os.path.exists(text_path):
                text_feat = np.load(text_path)
                # Ensure consistent dimensions
                if text_feat.shape != (self.feature_dims['text'],):
                    text_feat = np.zeros(self.feature_dims['text'])
            else:
                text_feat = np.zeros(self.feature_dims['text'])
            
            # Load audio features
            audio_path = os.path.join(self.feature_dir, 'audio', f'audio_feature_{dialogue_id}_{utt_id}.npy')
            if os.path.exists(audio_path):
                audio_feat = np.load(audio_path)
                # Ensure consistent dimensions
                if audio_feat.shape != (self.feature_dims['audio'],):
                    audio_feat = np.zeros(self.feature_dims['audio'])
            else:
                audio_feat = np.zeros(self.feature_dims['audio'])
            
            # Load video features
            video_path = os.path.join(self.feature_dir, 'video', f'video_feature_{dialogue_id}_{utt_id}.npy')
            if os.path.exists(video_path):
                video_feat = np.load(video_path)
                # Ensure consistent dimensions
                if video_feat.shape != (self.feature_dims['video'],):
                    video_feat = np.zeros(self.feature_dims['video'])
            else:
                video_feat = np.zeros(self.feature_dims['video'])
            
            text_features.append(text_feat)
            audio_features.append(audio_feat)
            video_features.append(video_feat)
        
        # Convert lists to tensors
        text_feat_tensor = torch.tensor(np.array(text_features), dtype=torch.float)
        audio_feat_tensor = torch.tensor(np.array(audio_features), dtype=torch.float)
        video_feat_tensor = torch.tensor(np.array(video_features), dtype=torch.float)
        unified_target_tensor = torch.tensor(dialogue['unified_target'], dtype=torch.long)  # Using long for class indices
        
        return {
            'dialogue_id': dialogue_id,
            'text_feat': text_feat_tensor,
            'audio_feat': audio_feat_tensor,
            'video_feat': video_feat_tensor,
            'unified_target': unified_target_tensor,
            'num_utterances': num_utterances
        }

# %%
# ===== 2. Updated Model Architecture with unified classifier =====
class MultiModalTransformer(nn.Module):
    def __init__(self, text_dim=768, audio_dim=1024, video_dim=2048, 
                 hidden_dim=512, num_heads=8, num_layers=4, dropout=0.1, num_classes=3):
        super().__init__()
        
        # Feature dimension for each modality
        self.text_dim = text_dim
        self.audio_dim = audio_dim
        self.video_dim = video_dim
        self.combined_dim = text_dim + audio_dim + video_dim
        self.num_classes = num_classes
        
        # Projection layers to map each modality to a common space
        self.text_proj = nn.Linear(text_dim, hidden_dim)
        self.audio_proj = nn.Linear(audio_dim, hidden_dim)
        self.video_proj = nn.Linear(video_dim, hidden_dim)
        
        # Feature fusion layer
        self.fusion_layer = nn.Linear(3 * hidden_dim, hidden_dim)
        
        # Cross-modal transformer encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim,
            nhead=num_heads,
            dim_feedforward=hidden_dim * 4,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        # Unified classifier for all three classes (neutral, anger, cause)
        self.unified_classifier = nn.Linear(hidden_dim, num_classes)
    
    def forward(self, text_feat, audio_feat, video_feat):
        """
        Args:
            text_feat: [batch_size, seq_len, text_dim]
            audio_feat: [batch_size, seq_len, audio_dim]
            video_feat: [batch_size, seq_len, video_dim]
        
        Returns:
            logits: [batch_size, seq_len, num_classes]
        """
        batch_size, seq_len = text_feat.shape[0], text_feat.shape[1]
        
        # Project each modality
        text_hidden = self.text_proj(text_feat)    # [B, seq_len, hidden_dim]
        audio_hidden = self.audio_proj(audio_feat) # [B, seq_len, hidden_dim]
        video_hidden = self.video_proj(video_feat) # [B, seq_len, hidden_dim]
        
        # Concat features from different modalities for each utterance
        concat_features = torch.cat([text_hidden, audio_hidden, video_hidden], dim=2)  # [B, seq_len, 3*hidden_dim]
        
        # Fuse modalities
        fused_features = self.fusion_layer(concat_features)  # [B, seq_len, hidden_dim]
        fused_features = F.relu(fused_features)
        
        # Apply transformer encoder for contextualization
        context_features = self.transformer(fused_features)  # [B, seq_len, hidden_dim]
        
        # Get predictions for each utterance
        logits = self.unified_classifier(context_features)  # [B, seq_len, num_classes]
        
        return logits

# %%
# ===== 3. Updated Training Functions =====
def train_epoch(model, dataloader, optimizer, device):
    model.train()
    total_loss = 0
    
    # Loss function - CrossEntropyLoss with class weights to handle imbalance
    # Approximate weights: neutral is most common, cause is most rare
    class_weights = torch.tensor([1.0, 4.0, 8.0], device=device)  # [neutral, anger, cause]
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    
    for batch in dataloader:
        # Move batch to device
        text_feat = batch['text_feat'].to(device)          # [B, seq_len, text_dim]
        audio_feat = batch['audio_feat'].to(device)        # [B, seq_len, audio_dim]
        video_feat = batch['video_feat'].to(device)        # [B, seq_len, video_dim]
        unified_target = batch['unified_target'].to(device)  # [B, seq_len]
        
        # Forward pass
        logits = model(text_feat, audio_feat, video_feat)  # [B, seq_len, num_classes]
        
        # Reshape for loss calculation
        B, S, C = logits.shape
        logits_flat = logits.view(-1, C)  # [B*S, num_classes]
        targets_flat = unified_target.view(-1)  # [B*S]
        
        # Calculate loss
        loss = criterion(logits_flat, targets_flat)
        
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        
        # Gradient clipping to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()
        total_loss += loss.item()
    
    return total_loss / len(dataloader)

# %%
def evaluate(model, dataloader, device):
    model.eval()
    total_utterances = 0
    total_anger_correct = 0
    total_cause_correct = 0
    total_pair_correct = 0
    
    dialogue_accuracies = []
    all_dialogue_preds = []
    all_dialogue_targets = []

    all_anger_preds = []
    all_anger_targets = []
    all_cause_preds = []
    all_cause_targets = []

    with torch.no_grad():
        for batch in dataloader:
            text_feat = batch['text_feat'].to(device)
            audio_feat = batch['audio_feat'].to(device)
            video_feat = batch['video_feat'].to(device)
            unified_target = batch['unified_target'].to(device)  # [B, S]
            num_utterances = batch['num_utterances']  # List of sequence lengths
            
            logits = model(text_feat, audio_feat, video_feat)  # [B, S, 3]
            preds = torch.argmax(logits, dim=2)  # [B, S]
            
            batch_size = unified_target.size(0)
            for i in range(batch_size):
                seq_len = num_utterances[i]
                pred = preds[i, :seq_len]      # [seq_len]
                target = unified_target[i, :seq_len]

                # -------- Dialogue-level metrics --------
                correct_predictions = (pred == target).sum().item()
                dialogue_accuracy = correct_predictions / seq_len
                dialogue_accuracies.append(dialogue_accuracy)

                pred_has_anger = (pred == 1).any()
                pred_has_cause = (pred == 2).any()
                target_has_anger = (target == 1).any()
                target_has_cause = (target == 2).any()

                all_dialogue_preds.append([pred_has_anger.cpu().item(), pred_has_cause.cpu().item()])
                all_dialogue_targets.append([target_has_anger.cpu().item(), target_has_cause.cpu().item()])

                # -------- Utterance-level metrics --------
                pred_anger = (pred == 1).float()
                target_anger = (target == 1).float()
                pred_cause = (pred == 2).float()
                target_cause = (target == 2).float()

                all_anger_preds.append(pred_anger.cpu().numpy())
                all_anger_targets.append(target_anger.cpu().numpy())
                all_cause_preds.append(pred_cause.cpu().numpy())
                all_cause_targets.append(target_cause.cpu().numpy())

                anger_correct = (pred_anger == target_anger).sum().item()
                cause_correct = (pred_cause == target_cause).sum().item()
                pair_correct = ((pred_anger == target_anger) & (pred_cause == target_cause)).sum().item()

                total_utterances += seq_len
                total_anger_correct += anger_correct
                total_cause_correct += cause_correct
                total_pair_correct += pair_correct

    # Flatten all lists
    all_anger_preds = np.concatenate([x.flatten() for x in all_anger_preds])
    all_anger_targets = np.concatenate([x.flatten() for x in all_anger_targets])
    all_cause_preds = np.concatenate([x.flatten() for x in all_cause_preds])
    all_cause_targets = np.concatenate([x.flatten() for x in all_cause_targets])

    all_dialogue_preds = np.array(all_dialogue_preds)
    all_dialogue_targets = np.array(all_dialogue_targets)

    # ---- Utterance-level metrics ----
    anger_f1 = f1_score(all_anger_targets, all_anger_preds, zero_division=0)
    anger_precision = precision_score(all_anger_targets, all_anger_preds, zero_division=0)
    anger_recall = recall_score(all_anger_targets, all_anger_preds, zero_division=0)

    cause_f1 = f1_score(all_cause_targets, all_cause_preds, zero_division=0)
    cause_precision = precision_score(all_cause_targets, all_cause_preds, zero_division=0)
    cause_recall = recall_score(all_cause_targets, all_cause_preds, zero_division=0)

    anger_accuracy = total_anger_correct / total_utterances if total_utterances else 0
    cause_accuracy = total_cause_correct / total_utterances if total_utterances else 0
    pair_accuracy = total_pair_correct / total_utterances if total_utterances else 0

    # ---- Dialogue-level metrics ----
    mean_dialogue_accuracy = sum(dialogue_accuracies) / len(dialogue_accuracies) if dialogue_accuracies else 0
    dialogue_anger_f1 = f1_score(all_dialogue_targets[:, 0], all_dialogue_preds[:, 0], zero_division=0) 
    dialogue_cause_f1 = f1_score(all_dialogue_targets[:, 1], all_dialogue_preds[:, 1], zero_division=0) 
    macro_f1 = (dialogue_anger_f1 + dialogue_cause_f1) / 2

    metrics = {
        # Dialogue-level metrics
        "mean_dialogue_accuracy": mean_dialogue_accuracy,
        "dialogue_anger_f1": dialogue_anger_f1,
        "dialogue_cause_f1": dialogue_cause_f1,
        "dialogue_macro_f1": macro_f1,

        # Utterance-level metrics
        "utterance_anger_f1": anger_f1,
        "utterance_anger_precision": anger_precision,
        "utterance_anger_recall": anger_recall,
        "utterance_anger_accuracy": anger_accuracy,

        "utterance_cause_f1": cause_f1,
        "utterance_cause_precision": cause_precision,
        "utterance_cause_recall": cause_recall,
        "utterance_cause_accuracy": cause_accuracy,

        "utterance_pair_accuracy": pair_accuracy,
        "num_dialogues": len(dialogue_accuracies),
        "num_utterances": total_utterances
    }

    return metrics

# %%
def collate_fn(batch):
    """
    Custom collate function to handle variable sequence lengths
    """
    # Get max sequence length in this batch
    max_len = max([item['text_feat'].shape[0] for item in batch])
    
    # Initialize batch tensors
    batch_size = len(batch)
    text_dim = batch[0]['text_feat'].shape[1]
    audio_dim = batch[0]['audio_feat'].shape[1]
    video_dim = batch[0]['video_feat'].shape[1]
    
    batch_text = torch.zeros(batch_size, max_len, text_dim)
    batch_audio = torch.zeros(batch_size, max_len, audio_dim)
    batch_video = torch.zeros(batch_size, max_len, video_dim)
    batch_unified = torch.zeros(batch_size, max_len, dtype=torch.long)  # Using long for class indices
    batch_num_utts = []
    
    # Fill in batch tensors
    for i, item in enumerate(batch):
        seq_len = item['text_feat'].shape[0]
        batch_text[i, :seq_len] = item['text_feat']
        batch_audio[i, :seq_len] = item['audio_feat']
        batch_video[i, :seq_len] = item['video_feat']
        batch_unified[i, :seq_len] = item['unified_target']
        batch_num_utts.append(seq_len)
    
    return {
        'dialogue_id': [item['dialogue_id'] for item in batch],
        'text_feat': batch_text,
        'audio_feat': batch_audio,
        'video_feat': batch_video,
        'unified_target': batch_unified,
        'num_utterances': batch_num_utts
    }

# ===== 5. Train/Val Split Function (unchanged) =====
def split_data(csv_file, val_ratio=0.1):
    """
    Split dialogues into training and validation sets
    """
    # Read the CSV file
    df = pd.read_csv(csv_file)
    
    # Get unique dialogue IDs
    dialogue_ids = df['Dialogue_ID'].unique()
    
    # Shuffle dialogue IDs
    np.random.shuffle(dialogue_ids)
    print("Dialogue ID LENGTH:", len(dialogue_ids))

    # Split dialogues
    split_idx = int(len(dialogue_ids) * (1 - val_ratio))
    train_dialogue_ids = dialogue_ids[:split_idx]
    val_dialogue_ids = dialogue_ids[split_idx:]
    
    return train_dialogue_ids, val_dialogue_ids

# ===== 6. Updated Main Training Loop =====
def train_model(csv_file, feature_dir, training_params):
    # Create full dataset to detect feature dimensions
    full_dataset = EmotionCauseDataset(csv_file, feature_dir)
    
    # Get detected feature dimensions
    feature_dims = full_dataset.feature_dims
    print(feature_dims)
    
    # Update model parameters based on detected dimensions
    model_params = {
        'text_dim': feature_dims.get('text', 768),
        'audio_dim': feature_dims.get('audio', 1024),
        'video_dim': feature_dims.get('video', 2048),
        'hidden_dim': 256,
        'num_heads': 4,
        'num_layers': 3,
        'dropout': 0.2,
        'num_classes': 3  # Unified classes: neutral, anger, cause
    }
    
    print(f"Using model parameters: {model_params}")
    
    # Split data into train and validation sets
    train_dialogue_ids, val_dialogue_ids = split_data(csv_file, val_ratio=0.1)
    
    # Filter datasets for train and validation
    train_dataset = torch.utils.data.Subset(
        full_dataset, 
        [i for i, d in enumerate(full_dataset.dialogues) if d['dialogue_id'] in train_dialogue_ids]
    )
    
    val_dataset = torch.utils.data.Subset(
        full_dataset, 
        [i for i, d in enumerate(full_dataset.dialogues) if d['dialogue_id'] in val_dialogue_ids]
    )
    
    print(f"Training on {len(train_dataset)} dialogues, validating on {len(val_dataset)} dialogues")
    
    # Create data loaders
    train_loader = DataLoader(
        train_dataset, 
        batch_size=training_params['batch_size'],
        shuffle=True,
        collate_fn=collate_fn
    )
    
    val_loader = DataLoader(
        val_dataset, 
        batch_size=training_params['batch_size'],
        shuffle=False,
        collate_fn=collate_fn
    )
    
    # Initialize model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    model = MultiModalTransformer(**model_params).to(device)
    
    # Optimizer and scheduler
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=training_params['learning_rate'],
        weight_decay=training_params['weight_decay']
    )
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, 
        mode='min', 
        factor=0.5, 
        patience=2, 
        verbose=True
    )
    
    # Training loop
    best_val_f1 = 0
    output_dir = training_params.get('output_dir', './models')
    os.makedirs(output_dir, exist_ok=True)
    
    for epoch in range(training_params['num_epochs']):
        # Train
        train_loss = train_epoch(model, train_loader, optimizer, device)
        
        # Evaluate
        metrics = evaluate(model, val_loader, device)

        val_f1 = metrics['dialogue_macro_f1']  # Updated key
        scheduler.step(1 - val_f1)  # Scheduler expects loss (1-F1)

        # Print progress
        print(f"\nEpoch {epoch+1}/{training_params['num_epochs']}:")
        print(f"  Train Loss: {train_loss:.4f}")
        print(f"  --- Dialogue-level Metrics ---")
        print(f"    Mean Dialogue Accuracy:    {metrics['mean_dialogue_accuracy']:.4f}")
        print(f"    Anger Detection F1:        {metrics['dialogue_anger_f1']:.4f}")
        print(f"    Cause Detection F1:        {metrics['dialogue_cause_f1']:.4f}")
        print(f"    Macro F1:                  {metrics['dialogue_macro_f1']:.4f}")
        print(f"    Number of Dialogues:       {metrics['num_dialogues']}")

        print(f"\n  --- Utterance-level Metrics ---")
        print(f"    Anger Accuracy:            {metrics['utterance_anger_accuracy']:.4f}")
        print(f"    Anger Precision:           {metrics['utterance_anger_precision']:.4f}")
        print(f"    Anger Recall:              {metrics['utterance_anger_recall']:.4f}")
        print(f"    Anger F1:                  {metrics['utterance_anger_f1']:.4f}")
        print()
        print(f"    Cause Accuracy:            {metrics['utterance_cause_accuracy']:.4f}")
        print(f"    Cause Precision:           {metrics['utterance_cause_precision']:.4f}")
        print(f"    Cause Recall:              {metrics['utterance_cause_recall']:.4f}")
        print(f"    Cause F1:                  {metrics['utterance_cause_f1']:.4f}")
        print()
        print(f"    Pair Accuracy:             {metrics['utterance_pair_accuracy']:.4f}")
        print(f"    Number of Utterances:      {metrics['num_utterances']}\n")

        # Save best model
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_f1': val_f1,
                'model_params': model_params
            }, os.path.join(output_dir, f"unified_best_model_epoch{epoch+1}.pt"))
            print(f"  ✅ Saved new best model with F1: {val_f1:.4f}")

        # Save final model
        torch.save({
            'epoch': training_params['num_epochs'],
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'model_params': model_params
        }, os.path.join(output_dir, "unified_final_model.pt"))

    
    return model, model_params

# %%
def predict_dialogue(model, csv_file, feature_dir, dialogue_id, model_params, device=None):
    """
    Predict unified class (neutral, anger, cause) for a specific dialogue with dialogue-level analysis
    """
    if device is None:
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    model.eval()
    
    # Read CSV file
    df = pd.read_csv(csv_file)
    dialogue_df = df[df['Dialogue_ID'] == dialogue_id].sort_values('Utterance_ID')
    
    if dialogue_df.empty:
        print(f"Dialogue ID {dialogue_id} not found in the CSV file")
        return None
    
    # Get utterances
    utterances = dialogue_df['Utterance'].tolist()
    num_utterances = len(utterances)
    
    # Load features
    text_features = []
    audio_features = []
    video_features = []
    
    for utt_id in range(num_utterances):
        # Load text features
        text_path = os.path.join(feature_dir, 'text', f'text_feature_{dialogue_id}_{utt_id}.npy')
        if os.path.exists(text_path):
            text_feat = np.load(text_path)
        else:
            text_feat = np.zeros(model_params['text_dim'])
        
        # Load audio features
        audio_path = os.path.join(feature_dir, 'audio', f'audio_feature_{dialogue_id}_{utt_id}.npy')
        if os.path.exists(audio_path):
            audio_feat = np.load(audio_path)
        else:
            audio_feat = np.zeros(model_params['audio_dim'])
        
        # Load video features
        video_path = os.path.join(feature_dir, 'video', f'video_feature_{dialogue_id}_{utt_id}.npy')
        if os.path.exists(video_path):
            video_feat = np.load(video_path)
        else:
            video_feat = np.zeros(model_params['video_dim'])
        
        text_features.append(text_feat)
        audio_features.append(audio_feat)
        video_features.append(video_feat)
    
    # Convert to tensors
    text_feat_tensor = torch.tensor(np.array(text_features), dtype=torch.float).unsqueeze(0).to(device)
    audio_feat_tensor = torch.tensor(np.array(audio_features), dtype=torch.float).unsqueeze(0).to(device)
    video_feat_tensor = torch.tensor(np.array(video_features), dtype=torch.float).unsqueeze(0).to(device)
    
    with torch.no_grad():
        # Forward pass
        logits = model(text_feat_tensor, audio_feat_tensor, video_feat_tensor)
        
        # Get probabilities and predictions
        probs = F.softmax(logits, dim=2).squeeze(0).cpu().numpy()  # [seq_len, num_classes]
        pred_class = np.argmax(probs, axis=1)  # [seq_len]
    
    # Class names mapping
    class_names = {0: "Neutral", 1: "Anger", 2: "Cause"}
    
    # Dialogue-level analysis
    anger_probs = probs[:, 1]  # Probabilities for anger class
    cause_probs = probs[:, 2]  # Probabilities for cause class
    
    # Find utterances with highest confidence for anger and cause
    max_anger_idx = np.argmax(anger_probs)
    max_cause_idx = np.argmax(cause_probs)
    
    # Get dialogue-level predictions
    has_anger = np.any(pred_class == 1)
    has_cause = np.any(pred_class == 2)
    
    # Prepare results
    dialogue_results = {
        'dialogue_id': dialogue_id,
        'has_anger': has_anger,
        'has_cause': has_cause,
        'anger_confidence': anger_probs[max_anger_idx],
        'cause_confidence': cause_probs[max_cause_idx],
        'most_likely_anger_utterance': {
            'utterance_id': max_anger_idx,
            'text': utterances[max_anger_idx],
            'confidence': anger_probs[max_anger_idx]
        },
        'most_likely_cause_utterance': {
            'utterance_id': max_cause_idx,
            'text': utterances[max_cause_idx],
            'confidence': cause_probs[max_cause_idx]
        },
        'utterances': []
    }
    
    # Add detailed utterance-level results
    for i in range(num_utterances):
        # Get probabilities for each class
        class_probs = {class_names[j]: probs[i, j] for j in range(3)}
        
        dialogue_results['utterances'].append({
            'utterance_id': i,
            'text': utterances[i],
            'speaker': dialogue_df.iloc[i]['Speaker'] if 'Speaker' in dialogue_df.columns else "Unknown",
            'original_label': dialogue_df.iloc[i]['Label'] if 'Label' in dialogue_df.columns else "Unknown",
            'predicted_class': class_names[pred_class[i]],
            'class_probabilities': class_probs
        })
    
    return dialogue_results

def print_dialogue_results(results):
    """
    Helper function to print dialogue prediction results in a readable format
    """
    if results is None:
        print("No results to display")
        return
    
    print("\n" + "="*80)
    print(f"Dialogue Analysis (ID: {results['dialogue_id']})")
    print("="*80)
    
    # Print dialogue-level predictions
    print("\nDialogue-Level Predictions:")
    print(f"Contains Anger: {'Yes' if results['has_anger'] else 'No'} (Confidence: {results['anger_confidence']:.3f})")
    print(f"Contains Cause: {'Yes' if results['has_cause'] else 'No'} (Confidence: {results['cause_confidence']:.3f})")
    
    # Print most likely anger and cause utterances
    print("\nMost Likely Anger Utterance:")
    print(f"ID: {results['most_likely_anger_utterance']['utterance_id']}")
    print(f"Text: {results['most_likely_anger_utterance']['text']}")
    print(f"Confidence: {results['most_likely_anger_utterance']['confidence']:.3f}")
    
    print("\nMost Likely Cause Utterance:")
    print(f"ID: {results['most_likely_cause_utterance']['utterance_id']}")
    print(f"Text: {results['most_likely_cause_utterance']['text']}")
    print(f"Confidence: {results['most_likely_cause_utterance']['confidence']:.3f}")
    
    # Print detailed utterance-level results
    print("\nDetailed Utterance Analysis:")
    print("-"*80)
    for utt in results['utterances']:
        print(f"\nUtterance {utt['utterance_id']} ({utt['speaker']}):")
        print(f"Text: {utt['text']}")
        print(f"Original Label: {utt['original_label']}")
        print(f"Predicted Class: {utt['predicted_class']}")
        print("Class Probabilities:")
        for class_name, prob in utt['class_probabilities'].items():
            print(f"  {class_name}: {prob:.3f}")
    print("="*80)

# %%
    # Set paths
csv_file = "makkari.csv"  # Path to your CSV file
feature_dir = "/home/klad/Desktop/Friends/features"  # Root directory for features
    
    # Define training parameters
training_params = {
        'batch_size': 8,
        'learning_rate': 2e-5,
        'weight_decay': 1e-4,
        'num_epochs': 20,
        'output_dir': './models'
    }
    
    # Train the model
print("Starting unified model training...")
model, model_params = train_model(csv_file, feature_dir, training_params)
    
print("Training completed!")
    
    # Example: Predict for a specific dialogue
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Starting unified model training...
# Feature dimensions: {'text': 768, 'audio': 1024, 'video': 2048}
# {'text': 768, 'audio': 1024, 'video': 2048}
# Using model parameters: {'text_dim': 768, 'audio_dim': 1024, 'video_dim': 2048, 'hidden_dim': 256, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.2, 'num_classes': 3}
# Dialogue ID LENGTH: 1282
# Training on 1153 dialogues, validating on 129 dialogues
# Using device: cuda
# /home/klad/anaconda3/envs/main/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20:
#   Train Loss: 0.9879
#   --- Dialogue-level Metrics ---
#     Mean Dialogue Accuracy:    0.5630
#     Anger Detection F1:        0.6237
#     Cause Detection F1:        0.6545
#     Macro F1:                  0.6391
#     Number of Dialogues:       129
#
#   --- Utterance-level Metrics ---
#     Anger Accuracy:            0.7879
#     Anger Precision:           0.3722
#     Anger Recall:              0.2310
#     Anger F1:                  0.2851
#
#     Cause Accuracy:            0.7797
#     Cause Precision:           0.2172
#     Cause Recall:              0.3405
#     Cause F1:                  0.2653
#
#     Pair Accuracy:             0.6130
#     Number of Utterances:      1584
#
#   ✅ Saved new best model with F1: 0.6391
#
# Epoch 2/20:
#   Train Loss: 0.9328
#   --- Dialogue-level Metrics ---
#     Mean Dialogue Accuracy:    0.6029
#     Anger Detection F1:        0.6667
#     Cause Detection F1:        0.6545
#     Macro F1:                  0.6606
#     Number of Dialogues:       129
#
#   --- Utterance-level Metrics ---
#     Anger Accuracy:            0.7860
#     Anger Precision:           0.3871
#     Anger Recall:              0.2897
#     Anger F1:                  0.3314
#
#     Cause Accuracy:            0.8213
#     Cause Precision:           0.2448
#     Cause Recall:              0.2541
#     Cause F1:                  0.2493
#
#     Pair Accuracy:             0.6515
#     Number of Utterances:      1584
#
#   ✅ Saved new best model with F1: 0.6606
#
# Epoch 3/20:
#   Train Loss: 0.9155
#   --- Dialogue-level Metrics ---
#     Mean Dialogue Accuracy:    0.6121
#     Anger Detection F1:        0.6939
#     Cause Detection F1:        0.5987
#     Macro F1:                  0.6463
#     Number of Dialogues:       129
#
#   --- Utterance-level Metrics ---
#     Anger Accuracy:            0.7740
#     Anger Precision:           0.3692
#     Anger Recall:              0.3310
#     Anger F1:                  0.3491
#
#     Cause Accuracy:            0.8409
#     Cause Precision:           0.2362
#     Cause Recall:              0.1622
#     Cause F1:                  0.1923
#
#     Pair Accuracy:             0.6547
#     Number of Utterances:      1584
#
#
# Epoch 4/20:
#   Train Loss: 0.9054
#   --- Dialogue-level Metrics ---
#     Mean Dialogue Accuracy:    0.5944
#     Anger Detection F1:        0.6804
#     Cause Detection F1:        0.6545
#     Macro F1:                  0.6675
#     Number of Dialogues:       129
#
#   --- Utterance-level Metrics ---
#     Anger Accuracy:            0.7765
#     Anger Precision:           0.3632
#     Anger Recall:              0.2931
#     Anger F1:                  0.3244
#
#     Cause Accuracy:            0.8169
#     Cause Precision:           0.2414
#     Cause Recall:              0.2649
#     Cause F1:                  0.2526
#
#     Pair Accuracy:             0.6376
#     Number of Utterances:      1584
#
#   ✅ Saved new best model with F1: 0.6675
#
# Epoch 5/20:
#   Train Loss: 0.8821
#   --- Dialogue-level Metrics ---
#     Mean Dialogue Accuracy:    0.5497
#     Anger Detection F1:        0.6597
#     Cause Detection F1:        0.6587
#     Macro F1:                  0.6592
#     Number of Dialogues:       129
#
#   --- Utterance-level Metrics ---
#     Anger Accuracy:            0.7734
#     Anger Precision:           0.3349
#     Anger Recall:              0.2414
#     Anger F1:                  0.2806
#
#     Cause Accuracy:            0.7532
#     Cause Precision:           0.1953
#     Cause Recall:              0.3568
#     Cause F1:                  0.2524
#
#     Pair Accuracy:             0.5846
#     Number of Utterances:      1584
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 16
#      14 # Train the model
#      15 print("Starting unified model training...")
# ---> 16 model, model_params = train_model(csv_file, feature_dir, training_params)
#      18 print("Training completed!")
#      20 # Example: Predict for a specific dialogue
#
# Cell In[29], line 142, in train_model(csv_file, feature_dir, training_params)
#     138 os.makedirs(output_dir, exist_ok=True)
#     140 for epoch in range(training_params['num_epochs']):
#     141     # Train
# --> 142     train_loss = train_epoch(model, train_loader, optimizer, device)
#     144     # Evaluate
#     145     metrics = evaluate(model, val_loader, device)
#
# Cell In[27], line 37, in train_epoch(model, dataloader, optimizer, device)
#      34     torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#      36     optimizer.step()
# ---> 37     total_loss += loss.item()
#      39 return total_loss / len(dataloader)
#
# KeyboardInterrupt:

# %%
import os
import torch

# Ask for input
input_id = int(input("Enter dialogue ID index: "))
some_id = input_id
some_id%=125

try:
    # Read the actual dialogue ID from good_dialogues.txt
    with open('test_dialogues.txt', 'r') as f:
        good_ids = [int(line.strip()) for line in f if line.strip().isdigit()]

    if some_id < 0 or some_id >= len(good_ids):
        raise ValueError(f"Invalid input index. Please enter a number between 0 and {len(good_ids)-1}")
    
    actual_dialogue_id = good_ids[some_id]
    print(f"Using dialogue ID: {actual_dialogue_id} (from index {input_id})")

    # Try to find the best model
    best_model_files = [f for f in os.listdir('./models') if f.startswith('unified_best_model_epoch')]
    
    if best_model_files:
        best_model_path = os.path.join('./models', sorted(best_model_files)[-1])  # Get latest best model
        print(f"Loading model from {best_model_path}")
        
        # Load model
        checkpoint = torch.load(best_model_path)
        saved_model_params = checkpoint['model_params']
        
        model = MultiModalTransformer(**saved_model_params).to(device)
        model.load_state_dict(checkpoint['model_state_dict'])
        
        # Predict for actual dialogue ID from good_dialogues.txt
        results = predict_dialogue(model, csv_file, feature_dir, actual_dialogue_id, saved_model_params, device)
        
        # Print results in a readable format
        print_dialogue_results(results)
    else:
        print("No best model found. Using the final trained model.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Using dialogue ID: 995 (from index 719271832)
# Loading model from ./models/unified_best_model_epoch9.pt
#
# ================================================================================
# Dialogue Analysis (ID: 995)
# ================================================================================
#
# Dialogue-Level Predictions:
# Contains Anger: Yes (Confidence: 0.493)
# Contains Cause: No (Confidence: 0.111)
#
# Most Likely Anger Utterance:
# ID: 0
# Text: Oh hey! There's some kids playing in the street, you wanna go down there and give them a project, ruin their day?
# Confidence: 0.493
#
# Most Likely Cause Utterance:
# ID: 1
# Text: Hey, if they have a ball maybe you can stick razor blades in it and teach them a new game, Gonna Need Stitches Ball.
# Confidence: 0.111
#
# Detailed Utterance Analysis:
# --------------------------------------------------------------------------------
#
# Utterance 0 (Chandler):
# Text: Oh hey! There's some kids playing in the street, you wanna go down there and give them a project, ruin their day?
# Original Label: anger
# Predicted Class: Anger
# Class Probabilities:
#   Neutral: 0.462
#   Anger: 0.493
#   Cause: 0.045
#
# Utterance 1 (Ross):
# Text: Hey, if they have a ball maybe you can stick razor blades in it and teach them a new game, Gonna Need Stitches Ball.
# Original Label: neutral
# Predicted Class: Neutral
# Class Probabilities:
#   Neutral: 0.697
#   Anger: 0.192
#   Cause: 0.111
# ================================================================================
# /tmp/ipykernel_17896/3397591097.py:28: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(best_model_path)

# %%
import os
import torch
import pandas as pd

# Load CSV and get dialogue IDs
csv_df = pd.read_csv(csv_file)
dialogue_ids = csv_df['Dialogue_ID'].unique()

# Helper: check if a label is meaningful
def is_good(label):
    return str(label).lower() not in ["neutral", "unknown", "none", "nan"]

# Load best model
try:
    best_model_files = [f for f in os.listdir('./models') if f.startswith('unified_best_model_epoch')]
    if best_model_files:
        best_model_path = os.path.join('./models', sorted(best_model_files)[-1])
        print(f"✅ Loading model from {best_model_path}")

        checkpoint = torch.load(best_model_path)
        saved_model_params = checkpoint['model_params']

        model = MultiModalTransformer(**saved_model_params).to(device)
        model.load_state_dict(checkpoint['model_state_dict'])
        model.eval()
    else:
        print("❌ No best model found. Using the final trained model.")
        raise FileNotFoundError

except Exception as e:
    print(f"❌ Error loading best model: {e}")
    exit()

# Define percentage threshold
threshold_percentage = 85  # Set your desired threshold (e.g., 60%)

# Loop through dialogues and check quality
good_dialogue_ids = []

for dialogue_id in dialogue_ids:
    try:
        results = predict_dialogue(model, csv_file, feature_dir, dialogue_id, saved_model_params, device)
        utterances = results.get('utterances', [])

        true_labels = [utt['original_label'] for utt in utterances]
        pred_labels = [utt['predicted_class'] for utt in utterances]
        # Convert both predicted and actual labels to lowercase
        true_labels = [label.lower() for label in true_labels]
        pred_labels = [label.lower() for label in pred_labels]

# Now compare them
        exact_match_percentage = sum([pred == act for pred, act in zip(pred_labels, true_labels)]) / len(pred_labels)

        print(true_labels, pred_labels)
        # Count exact matches between true and predicted labels
        exact_matches = sum(1 for true, pred in zip(true_labels, pred_labels) if true == pred)

        # Calculate percentage of exact matches
        match_percentage = (exact_matches / len(true_labels)) * 100

        if match_percentage >= threshold_percentage:  # Check if the match percentage meets the threshold
            good_dialogue_ids.append(dialogue_id)
            print(f"✅ Dialogue {dialogue_id} marked good (Exact matches: {exact_matches}, Match percentage: {match_percentage:.2f}%)")
        else:
            print(f"⚪ Dialogue {dialogue_id} skipped (low exact match percentage: {match_percentage:.2f}%)")

    except Exception as err:
        print(f"⚠️ Skipping Dialogue ID {dialogue_id} due to error: {err}")

# Save good dialogue IDs
output_file = "good_dialogues.txt"
with open(output_file, "w") as f:
    for d_id in good_dialogue_ids:
        f.write(f"{d_id}\n")

print(f"\n✅ Stored {len(good_dialogue_ids)} good dialogues in '{output_file}'")
# Out:
# ✅ Loading model from ./models/unified_best_model_epoch9.pt
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger'] ['neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral']
# ⚪ Dialogue 6 skipped (low exact match percentage: 63.64%)
# ['cause', 'anger'] ['cause', 'anger']
# ✅ Dialogue 7 marked good (Exact matches: 2, Match percentage: 100.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger']
# ✅ Dialogue 9 marked good (Exact matches: 13, Match percentage: 92.86%)
# /tmp/ipykernel_17896/3825525713.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(best_model_path)
# ['anger', 'cause', 'cause', 'cause', 'cause', 'neutral'] ['anger', 'cause', 'cause', 'anger', 'cause', 'neutral']
# ⚪ Dialogue 10 skipped (low exact match percentage: 83.33%)
# ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause']
# ⚪ Dialogue 11 skipped (low exact match percentage: 70.00%)
# ['neutral', 'neutral', 'cause', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'anger', 'cause', 'cause', 'cause', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'anger']
# ⚪ Dialogue 12 skipped (low exact match percentage: 66.67%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'neutral'] ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 15 skipped (low exact match percentage: 82.61%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 17 skipped (low exact match percentage: 72.73%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'cause', 'anger', 'cause', 'anger', 'cause', 'neutral']
# ⚪ Dialogue 21 skipped (low exact match percentage: 71.43%)
# ['neutral', 'anger', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'cause'] ['cause', 'anger', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'anger']
# ⚪ Dialogue 23 skipped (low exact match percentage: 33.33%)
# ['anger', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 28 marked good (Exact matches: 7, Match percentage: 87.50%)
# ['neutral', 'cause', 'neutral', 'cause', 'cause', 'anger', 'anger', 'anger', 'neutral', 'anger', 'anger', 'neutral', 'neutral'] ['cause', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 29 skipped (low exact match percentage: 53.85%)
# ['neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'neutral', 'anger', 'neutral', 'anger', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger']
# ⚪ Dialogue 30 skipped (low exact match percentage: 68.75%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral']
# ⚪ Dialogue 32 skipped (low exact match percentage: 52.63%)
# ['anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 38 skipped (low exact match percentage: 66.67%)
# ['anger', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger'] ['anger', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'anger', 'cause', 'anger']
# ⚪ Dialogue 39 skipped (low exact match percentage: 84.21%)
# ['anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause'] ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger']
# ⚪ Dialogue 40 skipped (low exact match percentage: 73.33%)
# ['neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['anger', 'anger', 'neutral', 'neutral', 'cause']
# ⚪ Dialogue 45 skipped (low exact match percentage: 20.00%)
# ['neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral'] ['anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'cause', 'anger', 'anger', 'cause', 'cause']
# ⚪ Dialogue 46 skipped (low exact match percentage: 46.67%)
# ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger']
# ✅ Dialogue 49 marked good (Exact matches: 21, Match percentage: 95.45%)
# ['neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral'] ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 50 skipped (low exact match percentage: 76.47%)
# ['neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger'] ['neutral', 'neutral', 'cause', 'cause', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger']
# ✅ Dialogue 51 marked good (Exact matches: 10, Match percentage: 90.91%)
# ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 54 skipped (low exact match percentage: 66.67%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 58 skipped (low exact match percentage: 70.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause'] ['neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'cause']
# ⚪ Dialogue 63 skipped (low exact match percentage: 62.50%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral'] ['anger', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'anger', 'anger']
# ⚪ Dialogue 64 skipped (low exact match percentage: 61.54%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'cause']
# ⚪ Dialogue 67 skipped (low exact match percentage: 60.00%)
# ['anger', 'neutral', 'cause', 'neutral'] ['anger', 'cause', 'cause', 'neutral']
# ⚪ Dialogue 68 skipped (low exact match percentage: 75.00%)
# ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'cause']
# ⚪ Dialogue 69 skipped (low exact match percentage: 71.43%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger']
# ✅ Dialogue 70 marked good (Exact matches: 8, Match percentage: 88.89%)
# ['neutral', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'anger'] ['neutral', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'neutral']
# ✅ Dialogue 74 marked good (Exact matches: 6, Match percentage: 85.71%)
# ['neutral', 'anger', 'anger', 'cause', 'cause', 'cause'] ['anger', 'anger', 'anger', 'cause', 'cause', 'cause']
# ⚪ Dialogue 78 skipped (low exact match percentage: 83.33%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'anger', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'cause', 'cause', 'neutral', 'cause', 'anger', 'cause', 'anger', 'anger', 'anger', 'anger']
# ⚪ Dialogue 81 skipped (low exact match percentage: 58.82%)
# ['neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral']
# ✅ Dialogue 82 marked good (Exact matches: 10, Match percentage: 90.91%)
# ['neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'neutral', 'anger', 'anger']
# ⚪ Dialogue 83 skipped (low exact match percentage: 75.00%)
# ['neutral', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral'] ['anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 84 marked good (Exact matches: 6, Match percentage: 85.71%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'cause', 'neutral', 'anger', 'anger', 'neutral']
# ⚪ Dialogue 89 skipped (low exact match percentage: 57.14%)
# ['anger'] ['anger']
# ✅ Dialogue 91 marked good (Exact matches: 1, Match percentage: 100.00%)
# ['anger', 'neutral'] ['anger', 'neutral']
# ✅ Dialogue 92 marked good (Exact matches: 2, Match percentage: 100.00%)
# ['neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'cause', 'cause', 'anger', 'cause', 'anger', 'anger', 'anger', 'neutral', 'cause', 'cause', 'anger', 'anger', 'anger', 'neutral', 'anger']
# ⚪ Dialogue 94 skipped (low exact match percentage: 31.25%)
# ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 95 skipped (low exact match percentage: 77.78%)
# ['neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'anger']
# ✅ Dialogue 97 marked good (Exact matches: 4, Match percentage: 100.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral']
# ✅ Dialogue 99 marked good (Exact matches: 18, Match percentage: 94.74%)
# ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause'] ['neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'cause', 'cause', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'cause', 'anger']
# ⚪ Dialogue 109 skipped (low exact match percentage: 38.10%)
# ['neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral'] ['anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 110 skipped (low exact match percentage: 66.67%)
# ['neutral', 'neutral', 'anger', 'anger', 'cause'] ['neutral', 'neutral', 'anger', 'anger', 'anger']
# ⚪ Dialogue 112 skipped (low exact match percentage: 80.00%)
# ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral'] ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral']
# ✅ Dialogue 113 marked good (Exact matches: 11, Match percentage: 100.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral'] ['neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 115 skipped (low exact match percentage: 75.00%)
# ['neutral', 'cause', 'neutral', 'cause', 'anger', 'neutral'] ['neutral', 'cause', 'neutral', 'cause', 'anger', 'cause']
# ⚪ Dialogue 118 skipped (low exact match percentage: 83.33%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger'] ['neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'cause', 'anger']
# ⚪ Dialogue 119 skipped (low exact match percentage: 76.92%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'cause'] ['cause', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'neutral']
# ⚪ Dialogue 121 skipped (low exact match percentage: 28.57%)
# ['neutral', 'anger', 'anger', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'anger'] ['anger', 'anger', 'anger', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'anger']
# ⚪ Dialogue 123 skipped (low exact match percentage: 72.73%)
# ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'cause', 'anger', 'anger', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 126 skipped (low exact match percentage: 53.85%)
# ['neutral', 'neutral', 'cause', 'neutral', 'cause', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'anger', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral']
# ⚪ Dialogue 129 skipped (low exact match percentage: 60.00%)
# ['anger', 'anger', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'anger', 'neutral', 'anger', 'anger', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'cause', 'neutral', 'anger', 'anger']
# ⚪ Dialogue 138 skipped (low exact match percentage: 58.82%)
# ['neutral', 'neutral', 'anger', 'cause', 'neutral', 'neutral'] ['neutral', 'cause', 'anger', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 139 skipped (low exact match percentage: 50.00%)
# ['neutral', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'cause', 'cause', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'cause']
# ⚪ Dialogue 145 skipped (low exact match percentage: 63.16%)
# ['neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 146 marked good (Exact matches: 12, Match percentage: 92.31%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 147 skipped (low exact match percentage: 75.00%)
# ['anger', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral'] ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'anger', 'cause', 'anger']
# ⚪ Dialogue 148 skipped (low exact match percentage: 61.90%)
# ['neutral', 'neutral', 'anger', 'cause'] ['neutral', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 150 skipped (low exact match percentage: 75.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'cause', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 151 skipped (low exact match percentage: 60.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'anger', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'cause', 'anger', 'anger', 'anger']
# ⚪ Dialogue 153 skipped (low exact match percentage: 84.62%)
# ['neutral', 'cause', 'anger', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'neutral'] ['neutral', 'cause', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral']
# ✅ Dialogue 154 marked good (Exact matches: 8, Match percentage: 88.89%)
# ['neutral', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['cause', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 156 skipped (low exact match percentage: 75.00%)
# ['cause', 'anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral'] ['cause', 'cause', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'anger']
# ⚪ Dialogue 163 skipped (low exact match percentage: 81.82%)
# ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 167 skipped (low exact match percentage: 76.92%)
# ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral'] ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral']
# ✅ Dialogue 168 marked good (Exact matches: 13, Match percentage: 86.67%)
# ['neutral', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'neutral'] ['anger', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 173 skipped (low exact match percentage: 70.00%)
# ['neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'cause', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 175 skipped (low exact match percentage: 75.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger']
# ✅ Dialogue 179 marked good (Exact matches: 18, Match percentage: 90.00%)
# ['anger', 'neutral', 'cause', 'neutral', 'neutral'] ['anger', 'neutral', 'cause', 'neutral', 'neutral']
# ✅ Dialogue 181 marked good (Exact matches: 5, Match percentage: 100.00%)
# ['neutral', 'cause', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'cause', 'neutral', 'anger', 'anger', 'anger', 'anger', 'cause', 'cause', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 182 skipped (low exact match percentage: 81.25%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'anger', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'cause', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'anger']
# ✅ Dialogue 184 marked good (Exact matches: 20, Match percentage: 90.91%)
# ['neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral']
# ⚪ Dialogue 188 skipped (low exact match percentage: 66.67%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral'] ['anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger']
# ⚪ Dialogue 189 skipped (low exact match percentage: 66.67%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 191 marked good (Exact matches: 6, Match percentage: 85.71%)
# ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'cause', 'cause', 'cause', 'cause', 'neutral', 'anger', 'neutral', 'cause', 'neutral']
# ⚪ Dialogue 195 skipped (low exact match percentage: 70.00%)
# ['neutral', 'anger', 'cause', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral'] ['neutral', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral']
# ⚪ Dialogue 200 skipped (low exact match percentage: 40.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'cause', 'neutral', 'neutral', 'cause', 'cause', 'anger']
# ✅ Dialogue 202 marked good (Exact matches: 13, Match percentage: 86.67%)
# ['neutral', 'anger', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'anger'] ['anger', 'anger', 'cause', 'anger', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 206 skipped (low exact match percentage: 78.95%)
# ['cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral'] ['cause', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'neutral']
# ✅ Dialogue 207 marked good (Exact matches: 17, Match percentage: 85.00%)
# ['cause', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 208 marked good (Exact matches: 14, Match percentage: 87.50%)
# ['anger', 'cause', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'cause', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral']
# ⚪ Dialogue 210 skipped (low exact match percentage: 81.82%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral'] ['neutral', 'anger', 'neutral', 'anger', 'neutral', 'cause', 'cause', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 212 skipped (low exact match percentage: 70.00%)
# ['cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'cause']
# ⚪ Dialogue 219 skipped (low exact match percentage: 69.23%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['cause', 'cause', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 228 skipped (low exact match percentage: 50.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 231 skipped (low exact match percentage: 66.67%)
# ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'anger']
# ⚪ Dialogue 232 skipped (low exact match percentage: 75.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'anger'] ['neutral', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'cause', 'neutral']
# ⚪ Dialogue 234 skipped (low exact match percentage: 60.00%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'cause', 'anger', 'anger', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 235 skipped (low exact match percentage: 50.00%)
# ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'cause', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'cause', 'cause', 'neutral', 'cause', 'cause', 'cause', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 236 skipped (low exact match percentage: 66.67%)
# ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 237 skipped (low exact match percentage: 83.33%)
# ['anger', 'sadness', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'cause'] ['neutral', 'anger', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'cause', 'anger', 'cause']
# ⚪ Dialogue 241 skipped (low exact match percentage: 64.29%)
# ['neutral', 'anger', 'neutral', 'cause', 'anger', 'cause', 'anger'] ['neutral', 'anger', 'neutral', 'cause', 'cause', 'anger', 'cause']
# ⚪ Dialogue 248 skipped (low exact match percentage: 57.14%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 251 marked good (Exact matches: 7, Match percentage: 100.00%)
# ['neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'anger'] ['cause', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger']
# ⚪ Dialogue 254 skipped (low exact match percentage: 60.00%)
# ['neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'cause', 'cause', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 255 skipped (low exact match percentage: 81.25%)
# ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral'] ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral']
# ⚪ Dialogue 256 skipped (low exact match percentage: 81.25%)
# ['neutral', 'cause', 'anger', 'anger'] ['cause', 'cause', 'neutral', 'neutral']
# ⚪ Dialogue 259 skipped (low exact match percentage: 25.00%)
# ['neutral', 'anger', 'neutral', 'cause', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'anger', 'cause', 'cause', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 260 skipped (low exact match percentage: 75.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'cause'] ['neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'cause']
# ✅ Dialogue 261 marked good (Exact matches: 8, Match percentage: 88.89%)
# ['neutral', 'neutral', 'neutral', 'cause', 'anger'] ['neutral', 'neutral', 'cause', 'neutral', 'anger']
# ⚪ Dialogue 262 skipped (low exact match percentage: 60.00%)
# ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'cause']
# ⚪ Dialogue 264 skipped (low exact match percentage: 78.95%)
# ['anger', 'neutral', 'anger', 'neutral', 'neutral'] ['anger', 'neutral', 'anger', 'neutral', 'neutral']
# ✅ Dialogue 265 marked good (Exact matches: 5, Match percentage: 100.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'neutral'] ['cause', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'neutral']
# ✅ Dialogue 271 marked good (Exact matches: 10, Match percentage: 90.91%)
# ['cause', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['cause', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger']
# ⚪ Dialogue 272 skipped (low exact match percentage: 77.78%)
# ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral'] ['neutral', 'anger', 'anger', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'anger', 'neutral']
# ⚪ Dialogue 273 skipped (low exact match percentage: 52.63%)
# ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'anger', 'cause', 'anger']
# ⚪ Dialogue 274 skipped (low exact match percentage: 53.85%)
# ['anger', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'cause', 'neutral', 'anger'] ['cause', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'cause', 'anger', 'anger', 'anger']
# ⚪ Dialogue 275 skipped (low exact match percentage: 41.18%)
# ['neutral', 'cause', 'neutral'] ['cause', 'neutral', 'neutral']
# ⚪ Dialogue 276 skipped (low exact match percentage: 33.33%)
# ['neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'neutral']
# ✅ Dialogue 277 marked good (Exact matches: 6, Match percentage: 85.71%)
# ['neutral', 'cause', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral'] ['cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'cause', 'neutral']
# ⚪ Dialogue 279 skipped (low exact match percentage: 50.00%)
# ['cause', 'anger', 'neutral'] ['cause', 'anger', 'neutral']
# ✅ Dialogue 280 marked good (Exact matches: 3, Match percentage: 100.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 285 skipped (low exact match percentage: 81.25%)
# ['neutral', 'cause', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'cause', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 287 skipped (low exact match percentage: 61.54%)
# ['neutral', 'cause', 'cause', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'anger', 'cause', 'cause', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'cause', 'anger']
# ⚪ Dialogue 288 skipped (low exact match percentage: 61.90%)
# ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger'] ['neutral', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'anger', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'anger']
# ⚪ Dialogue 295 skipped (low exact match percentage: 59.09%)
# ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'neutral']
# ⚪ Dialogue 296 skipped (low exact match percentage: 76.19%)
# ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'cause', 'cause', 'anger', 'neutral']
# ⚪ Dialogue 297 skipped (low exact match percentage: 80.00%)
# ['anger', 'anger', 'cause', 'neutral', 'neutral', 'anger', 'anger'] ['anger', 'anger', 'cause', 'cause', 'neutral', 'anger', 'anger']
# ✅ Dialogue 298 marked good (Exact matches: 6, Match percentage: 85.71%)
# ['neutral', 'neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 300 skipped (low exact match percentage: 80.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'cause'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'cause', 'anger', 'cause', 'cause', 'anger', 'neutral', 'cause']
# ⚪ Dialogue 301 skipped (low exact match percentage: 68.75%)
# ['neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral']
# ⚪ Dialogue 302 skipped (low exact match percentage: 63.64%)
# ['anger', 'neutral'] ['anger', 'neutral']
# ✅ Dialogue 303 marked good (Exact matches: 2, Match percentage: 100.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'anger'] ['cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'cause', 'anger', 'neutral']
# ⚪ Dialogue 304 skipped (low exact match percentage: 54.55%)
# ['neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'cause'] ['anger', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 312 skipped (low exact match percentage: 68.18%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 315 marked good (Exact matches: 9, Match percentage: 90.00%)
# ['neutral', 'neutral', 'cause', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'cause'] ['neutral', 'neutral', 'cause', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'cause']
# ✅ Dialogue 316 marked good (Exact matches: 9, Match percentage: 100.00%)
# ['neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger'] ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger']
# ⚪ Dialogue 317 skipped (low exact match percentage: 81.25%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 319 skipped (low exact match percentage: 73.91%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['anger', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 327 skipped (low exact match percentage: 75.00%)
# ['anger', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 328 marked good (Exact matches: 8, Match percentage: 88.89%)
# ['neutral', 'anger', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'anger', 'neutral', 'anger', 'neutral'] ['neutral', 'cause', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'anger', 'anger', 'anger', 'anger']
# ⚪ Dialogue 329 skipped (low exact match percentage: 72.73%)
# ['anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['anger', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'anger']
# ⚪ Dialogue 331 skipped (low exact match percentage: 70.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'cause']
# ⚪ Dialogue 332 skipped (low exact match percentage: 81.25%)
# ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause']
# ⚪ Dialogue 336 skipped (low exact match percentage: 76.19%)
# ['neutral', 'cause', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'anger', 'neutral'] ['neutral', 'cause', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 337 skipped (low exact match percentage: 65.00%)
# ['neutral', 'neutral', 'anger', 'neutral'] ['anger', 'neutral', 'neutral', 'anger']
# ⚪ Dialogue 339 skipped (low exact match percentage: 25.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'cause', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 342 skipped (low exact match percentage: 70.00%)
# ['anger', 'neutral', 'neutral', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'neutral', 'anger', 'anger', 'neutral', 'neutral'] ['anger', 'anger', 'cause', 'anger', 'anger', 'anger', 'anger', 'cause', 'anger', 'anger', 'anger', 'neutral', 'anger', 'anger', 'anger', 'neutral']
# ⚪ Dialogue 351 skipped (low exact match percentage: 56.25%)
# ['neutral', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'neutral'] ['neutral', 'anger', 'neutral', 'anger', 'neutral', 'anger', 'neutral']
# ⚪ Dialogue 352 skipped (low exact match percentage: 71.43%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 354 skipped (low exact match percentage: 72.22%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'cause', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'anger', 'anger', 'neutral']
# ⚪ Dialogue 356 skipped (low exact match percentage: 73.91%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'cause', 'neutral', 'cause', 'anger', 'anger', 'anger', 'neutral', 'cause']
# ⚪ Dialogue 358 skipped (low exact match percentage: 68.42%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'anger']
# ⚪ Dialogue 365 skipped (low exact match percentage: 80.00%)
# ...
# ⚪ Dialogue 2750 skipped (low exact match percentage: 69.57%)
# ['anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2752 skipped (low exact match percentage: 77.78%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2754 marked good (Exact matches: 18, Match percentage: 94.74%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2755 marked good (Exact matches: 17, Match percentage: 89.47%)
# ['neutral', 'neutral', 'cause', 'cause', 'cause', 'cause', 'cause', 'neutral', 'cause', 'anger', 'anger', 'anger', 'anger', 'cause', 'anger', 'neutral', 'anger', 'anger', 'cause', 'neutral', 'anger', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2756 skipped (low exact match percentage: 30.43%)
# ['anger', 'anger', 'cause', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2760 skipped (low exact match percentage: 25.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2761 marked good (Exact matches: 9, Match percentage: 90.00%)
# ['neutral', 'anger', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2763 skipped (low exact match percentage: 60.00%)
# ['neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2764 marked good (Exact matches: 8, Match percentage: 88.89%)
# ['neutral', 'cause', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2765 skipped (low exact match percentage: 73.33%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2770 skipped (low exact match percentage: 80.00%)
# ['anger', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2773 skipped (low exact match percentage: 58.33%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2775 skipped (low exact match percentage: 80.00%)
# ['anger', 'cause', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'anger', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2777 skipped (low exact match percentage: 38.89%)
# ['neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2779 skipped (low exact match percentage: 76.92%)
# ['neutral', 'anger', 'anger', 'anger', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2781 skipped (low exact match percentage: 20.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2782 skipped (low exact match percentage: 83.33%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2784 marked good (Exact matches: 12, Match percentage: 92.31%)
# ['neutral', 'anger', 'neutral', 'anger', 'anger', 'anger', 'anger', 'anger', 'cause', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2785 skipped (low exact match percentage: 20.00%)
# ['neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2786 marked good (Exact matches: 7, Match percentage: 87.50%)
# ['neutral', 'neutral', 'neutral', 'cause', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2787 skipped (low exact match percentage: 60.00%)
# ['anger', 'anger', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2791 skipped (low exact match percentage: 60.00%)
# ['anger', 'cause', 'anger', 'neutral', 'anger', 'anger', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2792 skipped (low exact match percentage: 37.50%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2794 marked good (Exact matches: 11, Match percentage: 91.67%)
# ['neutral', 'anger'] ['neutral', 'neutral']
# ⚪ Dialogue 2801 skipped (low exact match percentage: 50.00%)
# ['cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2803 marked good (Exact matches: 12, Match percentage: 85.71%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'cause'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2809 skipped (low exact match percentage: 69.23%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2811 marked good (Exact matches: 8, Match percentage: 88.89%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2812 skipped (low exact match percentage: 78.57%)
# ['anger', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2814 marked good (Exact matches: 12, Match percentage: 85.71%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2815 skipped (low exact match percentage: 73.33%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'cause', 'anger', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2818 skipped (low exact match percentage: 75.00%)
# ['neutral', 'anger', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2820 skipped (low exact match percentage: 75.00%)
# ['anger', 'anger', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'cause', 'neutral', 'cause'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2821 skipped (low exact match percentage: 58.82%)
# ['neutral', 'anger', 'anger', 'anger', 'neutral', 'cause', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2823 skipped (low exact match percentage: 50.00%)
# ['anger', 'neutral', 'neutral', 'neutral', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2824 skipped (low exact match percentage: 66.67%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2825 marked good (Exact matches: 20, Match percentage: 90.91%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'cause', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2827 marked good (Exact matches: 12, Match percentage: 85.71%)
# ['anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2833 skipped (low exact match percentage: 52.63%)
# ['neutral', 'neutral', 'cause', 'cause', 'neutral', 'anger', 'anger', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'anger', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2835 skipped (low exact match percentage: 61.11%)
# ['anger', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ✅ Dialogue 2836 marked good (Exact matches: 8, Match percentage: 88.89%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'neutral', 'cause', 'cause', 'anger', 'anger', 'anger', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2840 skipped (low exact match percentage: 50.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'anger', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2841 skipped (low exact match percentage: 72.73%)
# ['anger', 'cause', 'cause', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2845 skipped (low exact match percentage: 25.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'cause', 'neutral', 'cause', 'cause', 'cause', 'neutral', 'anger', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2847 skipped (low exact match percentage: 70.59%)
# ['neutral', 'cause', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2849 skipped (low exact match percentage: 78.57%)
# ['neutral', 'cause', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2850 skipped (low exact match percentage: 80.00%)
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'anger'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2853 skipped (low exact match percentage: 83.33%)
# ['neutral', 'cause', 'anger', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2855 skipped (low exact match percentage: 60.00%)
# ['anger', 'anger', 'anger', 'anger', 'anger', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'cause', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral'] ['neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral']
# ⚪ Dialogue 2860 skipped (low exact match percentage: 56.25%)
#
# ✅ Stored 267 good dialogues in 'good_dialogues.txt'
